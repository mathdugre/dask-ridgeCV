# %%
from dask_ml.datasets import make_regression
from sklearn.linear_model import Ridge
from dask_ml.linear_model import RidgeRegression

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:33437' processes=6 threads=24, memory=31.32 GiB>

# %%
X, y = make_regression(n_samples=10_000_000, chunks=(1000, 1000))

# %%
# %%timeit
# sklearn
ridge_ = Ridge()
ridge_.fit(X, y)
ridge_.predict(X)
ridge_.predict(X)
ridge_.score(X, y)
# Out:
# 2min 22s ± 3.95 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
# dask
ridge = RidgeRegression(solver="svd")
ridge.fit(X, y)
ridge.predict(X)
ridge.predict(X)
ridge.score(X, y)
# Out:
# 2min 38s ± 5.31 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
